# %% [markdown]
# Importar bibliotecas necessárias:
# sklearn.datasets para carregar datase IRIS
# train_test_split para dividir dataset em subconjuntos de treino e teste
# DecisionTreeClassifier para instanciar modelo de árvore de decisão
# accuracy_score para avaliação do modelo

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/carara/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1082, in launch_instance
#     app.start()
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "/home/carara/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "/home/carara/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/carara/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/home/carara/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/home/carara/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/carara/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/carara/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/carara/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_430393/2258199897.py", line 1, in <module>
#     from sklearn.datasets import load_iris
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/__init__.py", line 73, in <module>
#     from .base import clone  # noqa: E402
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/base.py", line 19, in <module>
#     from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/utils/__init__.py", line 9, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 20, in <module>
#     from .fixes import parse_version
#   File "/home/carara/.local/lib/python3.10/site-packages/sklearn/utils/fixes.py", line 20, in <module>
#     import pandas as pd
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/home/carara/.local/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/carara/.local/lib/python3.10/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# Carregar Dados:
# iris = load_iris()

# %%
iris = load_iris()

# %% [markdown]
# Preparar X(características) e y (classe):
# X = iris.data, y = iris.target

# %%
X = iris.data
y = iris.target

# %% [markdown]
# Dividir Dados entre treino e teste:
# X_train recebe características dos indíviduos para treino (70%);
# X_test recebe características dos indíviduos para teste (30%);
# y_train recebe as classes dos indíviduos para treino (70%);
# y_test recebe as classes dos indíviduos para teste (30%);

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# Instanciar Modelo. Para árvore de decisão é o seguinte.

# %%
model = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# Treinar Modelo (usa apenas 70% dos dados).

# %%
model.fit(X_train, y_train)

print("Modelo treinado com sucesso!")
# Out:
# Modelo treinado com sucesso!

# %% [markdown]
# Fazer Previsões. Analise apenas as características dos 30% restantes do dataset.Sem verificar suas classes.

# %%
predictions = model.predict(X_test)

# %% [markdown]
# Avaliação do modelo treinado usando a métrica acurácia:

# %%
accuracy = accuracy_score(y_test, predictions)

print(accuracy)
# Out:
# 0.9333333333333333
